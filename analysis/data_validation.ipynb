# %%
import pandas as pd

# %% [markdown]
# Databases

# %%
orders = '../databases/orders.csv'
order_items = '../databases/order_items.csv'
users = '../databases/users.csv'

# %% [markdown]
# Read csv files

# %%
orders_df = pd.read_csv(orders)
order_items_df = pd.read_csv(order_items)
users_df = pd.read_csv(users)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18852\1125601531.py:3: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   users_df = pd.read_csv(users)

# %% [markdown]
# Schema Validation

# %%
orders_df.info()

# if null type exist in created_at column then the data is not valid
# but if null exist in returned_at, shipped_at, and delivered at then is fine because it happen because customer canelled the order
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125422 entries, 0 to 125421
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      125422 non-null  int64
#  1   user_id       125422 non-null  int64
#  2   status        125422 non-null  object
#  3   gender        125422 non-null  object
#  4   created_at    125422 non-null  object
#  5   returned_at   12579 non-null   object
#  6   shipped_at    81456 non-null   object
#  7   delivered_at  44015 non-null   object
#  8   num_of_item   125422 non-null  int64
# dtypes: int64(3), object(6)
# memory usage: 8.6+ MB

# %%
order_items_df.info()
# shipped_at null can be the order already make but the product not shpping yet so it still valid
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181519 entries, 0 to 181518
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 181519 non-null  int64
#  1   order_id           181519 non-null  int64
#  2   user_id            181519 non-null  int64
#  3   product_id         181519 non-null  int64
#  4   inventory_item_id  181519 non-null  int64
#  5   status             181519 non-null  object
#  6   created_at         181519 non-null  object
#  7   shipped_at         117978 non-null  object
#  8   delivered_at       63726 non-null   object
#  9   returned_at        18270 non-null   object
#  10  sale_price         181519 non-null  float64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 15.2+ MB

# %%
users_df.info()
# existing null in city not gonna influence for the KPI analysis, so the data is valid
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              100000 non-null  int64
#  1   first_name      100000 non-null  object
#  2   last_name       100000 non-null  object
#  3   email           100000 non-null  object
#  4   age             100000 non-null  int64
#  5   gender          100000 non-null  object
#  6   state           100000 non-null  object
#  7   street_address  100000 non-null  object
#  8   postal_code     100000 non-null  object
#  9   city            99076 non-null   object
#  10  country         100000 non-null  object
#  11  latitude        100000 non-null  float64
#  12  longitude       100000 non-null  float64
#  13  traffic_source  100000 non-null  object
#  14  created_at      100000 non-null  object
#  15  user_geom       100000 non-null  object
# ...

# %% [markdown]
# Primary key validation

# %%
orders_df["order_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
users_df["id"].duplicated().sum()
# Out:
# np.int64(0)
